# %%
import pandas as pd
import numpy as np
import json

# %%
json_list = list()
with open('tweets_DM.json' , 'r') as file:
    for line in file:
        json_list.append(json.loads(line))

# %%
tweet_list = list()
for json in json_list:
    tweet_id = json['_source']['tweet']['tweet_id']
    text = json['_source']['tweet']['text']
    tweet_list.append([tweet_id, text])

# %%
# tweet_list

# %%
text_df = pd.DataFrame(tweet_list, columns=['tweet_id', 'text'])

# %%
emotion_df = pd.read_csv('emotion.csv')
# emotion_df

# %%
identification_df = pd.read_csv('data_identification.csv')
# identification_df

# %%
test_df = identification_df[identification_df['identification'] == 'test']
# test_df

# %%
train_df = text_df.merge(emotion_df, left_on='tweet_id', right_on='tweet_id')
# train_df

# %%
x_list = train_df['text'].to_list()
y_list = train_df['emotion'].to_list()

# %%
# x_list = list()
# for i in x:
#     x_list.append([i])

# %%
# y_list = list()
# for i in y:
#     y_list.append([i])

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x_list, y_list, test_size=0.2, random_state=42)
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# %%
print(len(train_x), len(train_y))
print(len(test_x), len(test_y))
print(len(valid_y), len(valid_y))
# Out:
# 931560 931560
# 291113 291113
# 232890 232890

# %%
import kashgari
from kashgari.tasks.classification import BiLSTM_Model
kashgari.config.use_cudnn_cell = True
import logging
logging.basicConfig(level='DEBUG')

model = BiLSTM_Model()
model.fit(train_x, 
          train_y, 
          valid_x, 
          valid_y,
          epochs=20,
         )
model.save('model/BiLSTM_20_Model')
# Out:
# WARNING:root:
# ╭─────────────────────────────────────────────────────────────────────────╮
# │ ◎ ○ ○ ░░░░░░░░░░░░░░░░░░░░░  Important Message  ░░░░░░░░░░░░░░░░░░░░░░░░│
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │              We renamed again for consistency and clarity.              │
# │                   From now on, it is all `kashgari`.                    │
# │  Changelog: https://github.com/BrikerMan/Kashgari/releases/tag/v1.0.0   │
# │                                                                         │
# │         | Backend          | pypi version   | desc           |          │
# │         | ---------------- | -------------- | -------------- |          │
# │         | TensorFlow 2.x   | kashgari 2.x.x | coming soon    |          │
# │         | TensorFlow 1.14+ | kashgari 1.x.x |                |          │
# │         | Keras            | kashgari 0.x.x | legacy version |          │
# │                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────╯
#
# WARNING:root:Unable to use CuDNN cell, no GPU available.
# WARNING:root:Sequence length will auto set at 95% of sequence length
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 137)]             0
# _________________________________________________________________
# layer_embedding (Embedding)  (None, 137, 100)          239000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               234496
# _________________________________________________________________
# dense (Dense)                (None, 8)                 2056
# =================================================================
# Total params: 475,552
# Trainable params: 475,552
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 14556/14556 [==============================] - 2157s 148ms/step - loss: 1.5156 - acc: 0.4467 - val_loss: 1.3362 - val_acc: 0.5136
# Epoch 2/20
# 14556/14556 [==============================] - 2161s 148ms/step - loss: 1.2668 - acc: 0.5396 - val_loss: 1.2180 - val_acc: 0.5577
# Epoch 3/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.1883 - acc: 0.5691 - val_loss: 1.1729 - val_acc: 0.5761
# Epoch 4/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.1464 - acc: 0.5846 - val_loss: 1.1533 - val_acc: 0.5823
# Epoch 5/20
# 14556/14556 [==============================] - 2170s 149ms/step - loss: 1.1202 - acc: 0.5943 - val_loss: 1.1455 - val_acc: 0.5847
# Epoch 6/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0986 - acc: 0.6019 - val_loss: 1.1345 - val_acc: 0.5894
# Epoch 7/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0830 - acc: 0.6081 - val_loss: 1.1263 - val_acc: 0.5921
# Epoch 8/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0700 - acc: 0.6128 - val_loss: 1.1226 - val_acc: 0.5954
# Epoch 9/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0592 - acc: 0.6171 - val_loss: 1.1236 - val_acc: 0.5941
# Epoch 10/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.0497 - acc: 0.6202 - val_loss: 1.1229 - val_acc: 0.5961
# Epoch 11/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.0421 - acc: 0.6233 - val_loss: 1.1214 - val_acc: 0.5956
# Epoch 12/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.0351 - acc: 0.6252 - val_loss: 1.1236 - val_acc: 0.5961
# Epoch 13/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.0292 - acc: 0.6274 - val_loss: 1.1306 - val_acc: 0.5933
# Epoch 14/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.0249 - acc: 0.6293 - val_loss: 1.1213 - val_acc: 0.5966
# Epoch 15/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0208 - acc: 0.6308 - val_loss: 1.1263 - val_acc: 0.5966
# Epoch 16/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0119 - acc: 0.6337 - val_loss: 1.1273 - val_acc: 0.5943
# Epoch 17/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0142 - acc: 0.6332 - val_loss: 1.1248 - val_acc: 0.5938
# Epoch 18/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0111 - acc: 0.6341 - val_loss: 1.1303 - val_acc: 0.5942
# Epoch 19/20
# 14556/14556 [==============================] - 2168s 149ms/step - loss: 1.0089 - acc: 0.6350 - val_loss: 1.1288 - val_acc: 0.5949
# Epoch 20/20
# 14556/14556 [==============================] - 2169s 149ms/step - loss: 1.0062 - acc: 0.6358 - val_loss: 1.1324 - val_acc: 0.5962

# %%
model = kashgari.utils.load_model('model/BiLSTM_20_Model')
model.evaluate(test_x, test_y)
# Out:
# WARNING:root:Sequence length will auto set at 95% of sequence length
#               precision    recall  f1-score   support
#
#        anger     0.6317    0.2635    0.3719      7946
# anticipation     0.6736    0.6056    0.6378     49984
#      disgust     0.5093    0.3975    0.4465     27669
#         fear     0.7098    0.4386    0.5422     12846
#          joy     0.5909    0.8248    0.6885    102943
#      sadness     0.5359    0.5298    0.5329     38745
#     surprise     0.6957    0.2294    0.3451      9816
#        trust     0.5912    0.4036    0.4797     41164
#
#     accuracy                         0.5953    291113
#    macro avg     0.6173    0.4616    0.5056    291113
# weighted avg     0.6000    0.5953    0.5799    291113

# %%
# import kashgari
# from kashgari.tasks.classification import BiLSTM_Model
# from kashgari.embeddings import BERTEmbedding
# kashgari.config.use_cudnn_cell = True
# import logging
# logging.basicConfig(level='DEBUG')

# bert_embed = BERTEmbedding('embedding/bert_base/',
#                            task=kashgari.CLASSIFICATION,
#                            sequence_length=100,
#                           )

# model = BiLSTM_Model(bert_embed)
# model.fit(train_x, 
#           train_y, 
#           valid_x, 
#           valid_y,
#           epochs=5,
#          )

# model.save('model/BERT_base_BiLSTM_Model')

# %%
# model = kashgari.utils.load_model('model/BERT_base_BiLSTM_Model')
# model.evaluate(test_x, test_y)

# %%
# train_df

# %%
# test_df

# %%
test_df = test_df.merge(text_df, left_on='tweet_id', right_on='tweet_id')
# test_df

# %%
text_list = test_df['text'].tolist()
# text_list

# %%
predict_list = model.predict(text_list)
predict_list
# Out:
# ['anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'anticipation',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'sadness',
#  'trust',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'trust',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'trust',
#  'sadness',
#  'fear',
#  'anger',
#  'trust',
#  'anticipation',
#  'disgust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'joy',
#  'disgust',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'trust',
#  'joy',
#  'anticipation',
#  'anger',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'fear',
#  'joy',
#  'anticipation',
#  'trust',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'fear',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'trust',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'fear',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'fear',
#  'anger',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'surprise',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'trust',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'anger',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'anger',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'disgust',
#  'joy',
#  'disgust',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'anger',
#  'trust',
#  'anger',
#  'joy',
#  'joy',
#  'surprise',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'trust',
#  'trust',
#  'sadness',
#  'sadness',
#  'joy',
#  'trust',
#  'anger',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'trust',
#  'sadness',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'disgust',
#  'disgust',
#  'fear',
#  'trust',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'sadness',
#  'trust',
#  'joy',
#  'sadness',
#  'fear',
#  'sadness',
#  'disgust',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'anger',
#  'sadness',
#  'sadness',
#  'trust',
#  'joy',
#  'anticipation',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'trust',
#  'sadness',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'trust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'anger',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'trust',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'anticipation',
#  'disgust',
#  'fear',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'fear',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'trust',
#  'joy',
#  'anger',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'anticipation',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'disgust',
#  'trust',
#  'sadness',
#  'joy',
#  'trust',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'trust',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'disgust',
#  'anticipation',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'fear',
#  'joy',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'fear',
#  'sadness',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'fear',
#  'trust',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'fear',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'trust',
#  'joy',
#  'trust',
#  'sadness',
#  'trust',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'fear',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  ...]

# %%
test_df['predict'] = predict_list
# test_df

# %%
output_df = test_df[['tweet_id', 'predict']]
output_df = output_df.rename(columns={'tweet_id':'id', 'predict':'emotion'})
# output_df

# %%
output_df.to_csv('../output/BiLSTM_20_Model.csv', index=False, header=True)
