# %%
import pandas as pd
import numpy as np
import json

# %%
json_list = list()
with open('tweets_DM.json' , 'r') as file:
    for line in file:
        json_list.append(json.loads(line))

# %%
tweet_list = list()
for json in json_list:
    tweet_id = json['_source']['tweet']['tweet_id']
    text = json['_source']['tweet']['text']
    tweet_list.append([tweet_id, text])

# %%
# tweet_list

# %%
text_df = pd.DataFrame(tweet_list, columns=['tweet_id', 'text'])

# %%
emotion_df = pd.read_csv('emotion.csv')
# emotion_df

# %%
identification_df = pd.read_csv('data_identification.csv')
# identification_df

# %%
test_df = identification_df[identification_df['identification'] == 'test']
# test_df

# %%
train_df = text_df.merge(emotion_df, left_on='tweet_id', right_on='tweet_id')
# train_df

# %%
x_list = train_df['text'].to_list()
y_list = train_df['emotion'].to_list()

# %%
# x_list = list()
# for i in x:
#     x_list.append([i])

# %%
# y_list = list()
# for i in y:
#     y_list.append([i])

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x_list, y_list, test_size=0.2, random_state=42)
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# %%
print(len(train_x), len(train_y))
print(len(test_x), len(test_y))
print(len(valid_y), len(valid_y))
# Out:
# 931560 931560
# 291113 291113
# 232890 232890

# %%
import kashgari
from kashgari.tasks.classification import BiLSTM_Model
kashgari.config.use_cudnn_cell = True
import logging
logging.basicConfig(level='DEBUG')

model = BiLSTM_Model()
model.fit(train_x, 
          train_y, 
          valid_x, 
          valid_y,
          epochs=40,
         )
model.save('model/BiLSTM_40_Model')
# Out:
# WARNING:root:
# ╭─────────────────────────────────────────────────────────────────────────╮
# │ ◎ ○ ○ ░░░░░░░░░░░░░░░░░░░░░  Important Message  ░░░░░░░░░░░░░░░░░░░░░░░░│
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │              We renamed again for consistency and clarity.              │
# │                   From now on, it is all `kashgari`.                    │
# │  Changelog: https://github.com/BrikerMan/Kashgari/releases/tag/v1.0.0   │
# │                                                                         │
# │         | Backend          | pypi version   | desc           |          │
# │         | ---------------- | -------------- | -------------- |          │
# │         | TensorFlow 2.x   | kashgari 2.x.x | coming soon    |          │
# │         | TensorFlow 1.14+ | kashgari 1.x.x |                |          │
# │         | Keras            | kashgari 0.x.x | legacy version |          │
# │                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────╯
#
# WARNING:root:Unable to use CuDNN cell, no GPU available.
# WARNING:root:Sequence length will auto set at 95% of sequence length
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 137)]             0
# _________________________________________________________________
# layer_embedding (Embedding)  (None, 137, 100)          239000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               234496
# _________________________________________________________________
# dense (Dense)                (None, 8)                 2056
# =================================================================
# Total params: 475,552
# Trainable params: 475,552
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 14556/14556 [==============================] - 1806s 124ms/step - loss: 1.5061 - acc: 0.4492 - val_loss: 1.3265 - val_acc: 0.5201
# Epoch 2/40
# 14556/14556 [==============================] - 1807s 124ms/step - loss: 1.2523 - acc: 0.5452 - val_loss: 1.2034 - val_acc: 0.5642
# Epoch 3/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 1.1782 - acc: 0.5725 - val_loss: 1.1679 - val_acc: 0.5765
# Epoch 4/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 1.1396 - acc: 0.5870 - val_loss: 1.1500 - val_acc: 0.5843
# Epoch 5/40
# 14556/14556 [==============================] - 1811s 124ms/step - loss: 1.1138 - acc: 0.5970 - val_loss: 1.1345 - val_acc: 0.5900
# Epoch 6/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0947 - acc: 0.6040 - val_loss: 1.1311 - val_acc: 0.5920
# Epoch 7/40
# 14556/14556 [==============================] - 1812s 124ms/step - loss: 1.0796 - acc: 0.6096 - val_loss: 1.1285 - val_acc: 0.5928
# Epoch 8/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0673 - acc: 0.6142 - val_loss: 1.1241 - val_acc: 0.5942
# Epoch 9/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0567 - acc: 0.6184 - val_loss: 1.1209 - val_acc: 0.5955
# Epoch 10/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 1.0483 - acc: 0.6214 - val_loss: 1.1256 - val_acc: 0.5948
# Epoch 11/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 1.0413 - acc: 0.6237 - val_loss: 1.1169 - val_acc: 0.5976
# Epoch 12/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0349 - acc: 0.6259 - val_loss: 1.1155 - val_acc: 0.5992
# Epoch 13/40
# 14556/14556 [==============================] - 1820s 125ms/step - loss: 1.0284 - acc: 0.6280 - val_loss: 1.1211 - val_acc: 0.5952
# Epoch 14/40
# 14556/14556 [==============================] - 1833s 126ms/step - loss: 1.0243 - acc: 0.6294 - val_loss: 1.1174 - val_acc: 0.5979
# Epoch 15/40
# 14556/14556 [==============================] - 1811s 124ms/step - loss: 1.0200 - acc: 0.6314 - val_loss: 1.1192 - val_acc: 0.5973
# Epoch 16/40
# 14556/14556 [==============================] - 1850s 127ms/step - loss: 1.0165 - acc: 0.6326 - val_loss: 1.1241 - val_acc: 0.5971
# Epoch 17/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0131 - acc: 0.6338 - val_loss: 1.1206 - val_acc: 0.5975
# Epoch 18/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 1.0109 - acc: 0.6347 - val_loss: 1.1173 - val_acc: 0.5990
# Epoch 19/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0080 - acc: 0.6360 - val_loss: 1.1212 - val_acc: 0.5977
# Epoch 20/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 1.0046 - acc: 0.6370 - val_loss: 1.1258 - val_acc: 0.5968
# Epoch 21/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 1.0026 - acc: 0.6379 - val_loss: 1.1248 - val_acc: 0.5963
# Epoch 22/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 1.0013 - acc: 0.6385 - val_loss: 1.1270 - val_acc: 0.5958
# Epoch 23/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 0.9997 - acc: 0.6387 - val_loss: 1.1209 - val_acc: 0.5971
# Epoch 24/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 0.9987 - acc: 0.6388 - val_loss: 1.1287 - val_acc: 0.5978
# Epoch 25/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 0.9956 - acc: 0.6405 - val_loss: 1.1206 - val_acc: 0.5980
# Epoch 26/40
# 14556/14556 [==============================] - 1811s 124ms/step - loss: 0.9942 - acc: 0.6408 - val_loss: 1.1289 - val_acc: 0.5970
# Epoch 27/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 0.9956 - acc: 0.6403 - val_loss: 1.1281 - val_acc: 0.5970
# Epoch 28/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 0.9970 - acc: 0.6402 - val_loss: 1.1293 - val_acc: 0.5953
# Epoch 29/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 1.0006 - acc: 0.6385 - val_loss: 1.1275 - val_acc: 0.5980
# Epoch 30/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 0.9947 - acc: 0.6406 - val_loss: 1.1268 - val_acc: 0.5987
# Epoch 31/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 0.9947 - acc: 0.6406 - val_loss: 1.1265 - val_acc: 0.5989
# Epoch 32/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 0.9906 - acc: 0.6419 - val_loss: 1.1205 - val_acc: 0.5972
# Epoch 33/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 0.9918 - acc: 0.6416 - val_loss: 1.1249 - val_acc: 0.5981
# Epoch 34/40
# 14556/14556 [==============================] - 1809s 124ms/step - loss: 0.9911 - acc: 0.6423 - val_loss: 1.1321 - val_acc: 0.5975
# Epoch 35/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 0.9896 - acc: 0.6423 - val_loss: 1.1303 - val_acc: 0.5966
# Epoch 36/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 0.9897 - acc: 0.6423 - val_loss: 1.1279 - val_acc: 0.5970
# Epoch 37/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 0.9881 - acc: 0.6427 - val_loss: 1.1288 - val_acc: 0.5963
# Epoch 38/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 0.9885 - acc: 0.6429 - val_loss: 1.1232 - val_acc: 0.5973
# Epoch 39/40
# 14556/14556 [==============================] - 1808s 124ms/step - loss: 0.9875 - acc: 0.6426 - val_loss: 1.1216 - val_acc: 0.5991
# Epoch 40/40
# 14556/14556 [==============================] - 1810s 124ms/step - loss: 0.9869 - acc: 0.6437 - val_loss: 1.1328 - val_acc: 0.5932

# %%
model = kashgari.utils.load_model('model/BiLSTM_40_Model')
model.evaluate(test_x, test_y)
# Out:
# WARNING:root:Sequence length will auto set at 95% of sequence length
#               precision    recall  f1-score   support
#
#        anger     0.5789    0.2718    0.3700      7946
# anticipation     0.6917    0.5969    0.6408     49984
#      disgust     0.4831    0.4061    0.4413     27669
#         fear     0.6687    0.4585    0.5440     12846
#          joy     0.6213    0.7834    0.6930    102943
#      sadness     0.4762    0.6048    0.5329     38745
#     surprise     0.6871    0.2400    0.3558      9816
#        trust     0.5831    0.4211    0.4890     41164
#
#     accuracy                         0.5939    291113
#    macro avg     0.5988    0.4728    0.5083    291113
# weighted avg     0.5987    0.5939    0.5832    291113

# %%
# import kashgari
# from kashgari.tasks.classification import BiLSTM_Model
# from kashgari.embeddings import BERTEmbedding
# kashgari.config.use_cudnn_cell = True
# import logging
# logging.basicConfig(level='DEBUG')

# bert_embed = BERTEmbedding('embedding/bert_base/',
#                            task=kashgari.CLASSIFICATION,
#                            sequence_length=100,
#                           )

# model = BiLSTM_Model(bert_embed)
# model.fit(train_x, 
#           train_y, 
#           valid_x, 
#           valid_y,
#           epochs=5,
#          )

# model.save('model/BERT_base_BiLSTM_Model')

# %%
# model = kashgari.utils.load_model('model/BERT_base_BiLSTM_Model')
# model.evaluate(test_x, test_y)

# %%
# train_df

# %%
# test_df

# %%
test_df = test_df.merge(text_df, left_on='tweet_id', right_on='tweet_id')
# test_df

# %%
text_list = test_df['text'].tolist()
# text_list

# %%
predict_list = model.predict(text_list)
predict_list
# Out:
# ['fear',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'trust',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'anticipation',
#  'trust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'anticipation',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'trust',
#  'trust',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'anticipation',
#  'sadness',
#  'trust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'disgust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'trust',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'joy',
#  'disgust',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'disgust',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'disgust',
#  'trust',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'trust',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'surprise',
#  'trust',
#  'disgust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'disgust',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'surprise',
#  'joy',
#  'anger',
#  'trust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'trust',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'trust',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'joy',
#  'trust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'anticipation',
#  'trust',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'fear',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'disgust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'disgust',
#  'disgust',
#  'fear',
#  'sadness',
#  'joy',
#  'fear',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'trust',
#  'disgust',
#  'sadness',
#  'trust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'trust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'fear',
#  'anger',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'joy',
#  'disgust',
#  'fear',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'surprise',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'disgust',
#  'sadness',
#  'trust',
#  'anger',
#  'trust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'trust',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'trust',
#  'trust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'joy',
#  'surprise',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'fear',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'trust',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'joy',
#  'fear',
#  'disgust',
#  'joy',
#  'disgust',
#  'sadness',
#  'fear',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'fear',
#  'joy',
#  'sadness',
#  'trust',
#  'fear',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'surprise',
#  'fear',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'disgust',
#  'sadness',
#  'disgust',
#  'sadness',
#  'fear',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'surprise',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'surprise',
#  'joy',
#  'disgust',
#  'trust',
#  'disgust',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'trust',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'surprise',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'trust',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'anticipation',
#  'fear',
#  'sadness',
#  'sadness',
#  'disgust',
#  'trust',
#  'joy',
#  'trust',
#  'anticipation',
#  'trust',
#  'trust',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'anger',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'disgust',
#  'trust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'fear',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'anger',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'surprise',
#  'disgust',
#  'anticipation',
#  'trust',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'fear',
#  'joy',
#  'anticipation',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'trust',
#  'joy',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'trust',
#  'trust',
#  'joy',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'fear',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'joy',
#  'anger',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'trust',
#  'joy',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'trust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'fear',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'fear',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'anger',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'disgust',
#  'trust',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'trust',
#  'sadness',
#  'trust',
#  ...]

# %%
test_df['predict'] = predict_list
# test_df

# %%
output_df = test_df[['tweet_id', 'predict']]
output_df = output_df.rename(columns={'tweet_id':'id', 'predict':'emotion'})
# output_df

# %%
output_df.to_csv('../output/BiLSTM_40_Model.csv', index=False, header=True)
