# %%
import pandas as pd
import numpy as np
import json

# %%
json_list = list()
with open('tweets_DM.json' , 'r') as file:
    for line in file:
        json_list.append(json.loads(line))

# %%
tweet_list = list()
for json in json_list:
    tweet_id = json['_source']['tweet']['tweet_id']
    hashtags = json['_source']['tweet']['hashtags']
    hashtag = ' '.join(hashtags)
    text = json['_source']['tweet']['text']
    text = text + ' ' + hashtag
    tweet_list.append([tweet_id, text])

# %%
text_df = pd.DataFrame(tweet_list, columns=['tweet_id', 'text'])

# %%
emotion_df = pd.read_csv('emotion.csv')
# emotion_df

# %%
identification_df = pd.read_csv('data_identification.csv')
# identification_df

# %%
test_df = identification_df[identification_df['identification'] == 'test']
# test_df

# %%
train_df = text_df.merge(emotion_df, left_on='tweet_id', right_on='tweet_id')
# train_df

# %%
x_list = train_df['text'].to_list()
y_list = train_df['emotion'].to_list()

# %%
# x_list = list()
# for i in x:
#     x_list.append([i])

# %%
# y_list = list()
# for i in y:
#     y_list.append([i])

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x_list, y_list, test_size=0.2, random_state=42)
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# %%
print(len(train_x), len(train_y))
print(len(test_x), len(test_y))
print(len(valid_y), len(valid_y))
# Out:
# 931560 931560
# 291113 291113
# 232890 232890

# %%
import kashgari
from kashgari.tasks.classification import BiLSTM_Model
kashgari.config.use_cudnn_cell = True
import logging
logging.basicConfig(level='DEBUG')

model = BiLSTM_Model()
model.fit(train_x, 
          train_y, 
          valid_x, 
          valid_y,
          epochs=50,
         )
model.save('model/BiLSTM_epoch_50')
# Out:
# WARNING:root:
# ╭─────────────────────────────────────────────────────────────────────────╮
# │ ◎ ○ ○ ░░░░░░░░░░░░░░░░░░░░░  Important Message  ░░░░░░░░░░░░░░░░░░░░░░░░│
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │              We renamed again for consistency and clarity.              │
# │                   From now on, it is all `kashgari`.                    │
# │  Changelog: https://github.com/BrikerMan/Kashgari/releases/tag/v1.0.0   │
# │                                                                         │
# │         | Backend          | pypi version   | desc           |          │
# │         | ---------------- | -------------- | -------------- |          │
# │         | TensorFlow 2.x   | kashgari 2.x.x | coming soon    |          │
# │         | TensorFlow 1.14+ | kashgari 1.x.x |                |          │
# │         | Keras            | kashgari 0.x.x | legacy version |          │
# │                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────╯
#
# WARNING:root:Unable to use CuDNN cell, no GPU available.
# WARNING:root:Sequence length will auto set at 95% of sequence length
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 165)]             0
# _________________________________________________________________
# layer_embedding (Embedding)  (None, 165, 100)          258800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               234496
# _________________________________________________________________
# dense (Dense)                (None, 8)                 2056
# =================================================================
# Total params: 495,352
# Trainable params: 495,352
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0046 - acc: 0.6364 - val_loss: 1.1324 - val_acc: 0.5961
# Epoch 41/50
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0089 - acc: 0.6349 - val_loss: 1.1334 - val_acc: 0.5937
# Epoch 42/50
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0181 - acc: 0.6314 - val_loss: 1.1400 - val_acc: 0.5896
# Epoch 43/50
# 14556/14556 [==============================] - 2905s 200ms/step - loss: 1.0167 - acc: 0.6319 - val_loss: 1.1316 - val_acc: 0.5942
# Epoch 44/50
# 14556/14556 [==============================] - 2904s 200ms/step - loss: 1.0227 - acc: 0.6296 - val_loss: 1.1277 - val_acc: 0.5959
# Epoch 45/50
# 14556/14556 [==============================] - 2907s 200ms/step - loss: 1.0150 - acc: 0.6328 - val_loss: 1.1346 - val_acc: 0.5939
# Epoch 46/50
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0119 - acc: 0.6341 - val_loss: 1.1279 - val_acc: 0.5947
# Epoch 47/50
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0101 - acc: 0.6342 - val_loss: 1.1328 - val_acc: 0.5946
# Epoch 48/50
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0082 - acc: 0.6355 - val_loss: 1.1302 - val_acc: 0.5940
# Epoch 49/50
# 14556/14556 [==============================] - 2906s 200ms/step - loss: 1.0062 - acc: 0.6361 - val_loss: 1.1287 - val_acc: 0.5953
# Epoch 50/50
# 14556/14556 [==============================] - 2907s 200ms/step - loss: 1.0054 - acc: 0.6364 - val_loss: 1.1337 - val_acc: 0.5950

# %%
model = kashgari.utils.load_model('model/BiLSTM_epoch_50')
model.evaluate(test_x, test_y)
# Out:
# WARNING:root:Sequence length will auto set at 95% of sequence length
#               precision    recall  f1-score   support
#
#        anger     0.6351    0.2576    0.3666      7946
# anticipation     0.6842    0.6008    0.6398     49984
#      disgust     0.4485    0.4757    0.4617     27669
#         fear     0.7059    0.4441    0.5452     12846
#          joy     0.6008    0.8117    0.6905    102943
#      sadness     0.5139    0.5318    0.5227     38745
#     surprise     0.7198    0.2298    0.3484      9816
#        trust     0.6304    0.3713    0.4673     41164
#
#     accuracy                         0.5931    291113
#    macro avg     0.6173    0.4654    0.5053    291113
# weighted avg     0.6028    0.5931    0.5794    291113

# %%
# model = kashgari.utils.load_model('model/BERT_base_BiLSTM_Model')
# model.evaluate(test_x, test_y)

# %%
# train_df

# %%
# test_df

# %%
test_df = test_df.merge(text_df, left_on='tweet_id', right_on='tweet_id')
# test_df

# %%
text_list = test_df['text'].tolist()
# text_list

# %%
predict_list = model.predict(text_list)
predict_list
# Out:
# ['joy',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'trust',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'disgust',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'anticipation',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'trust',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'trust',
#  'joy',
#  'anticipation',
#  'disgust',
#  'sadness',
#  'trust',
#  'sadness',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'trust',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'disgust',
#  'fear',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'fear',
#  'disgust',
#  'surprise',
#  'fear',
#  'sadness',
#  'sadness',
#  'trust',
#  'trust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'trust',
#  'disgust',
#  'sadness',
#  'sadness',
#  'disgust',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'trust',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'trust',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'trust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'trust',
#  'joy',
#  'joy',
#  'trust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'anger',
#  'anticipation',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'disgust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'disgust',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'joy',
#  'trust',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'sadness',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'surprise',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'trust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'trust',
#  'sadness',
#  'disgust',
#  'disgust',
#  'fear',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'disgust',
#  'fear',
#  'surprise',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'disgust',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'fear',
#  'trust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'trust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'fear',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'trust',
#  'anticipation',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'trust',
#  'sadness',
#  'anger',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'joy',
#  'trust',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'sadness',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'joy',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'disgust',
#  'anticipation',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'trust',
#  'sadness',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'anticipation',
#  'disgust',
#  'joy',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'disgust',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'anger',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'sadness',
#  'anticipation',
#  'joy',
#  'trust',
#  'joy',
#  'anger',
#  'joy',
#  'disgust',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'joy',
#  'anticipation',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'disgust',
#  'joy',
#  'sadness',
#  'anger',
#  'trust',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'surprise',
#  'sadness',
#  'anticipation',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'trust',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'sadness',
#  'anticipation',
#  'joy',
#  'fear',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'anticipation',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'disgust',
#  'disgust',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'anticipation',
#  'trust',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'anticipation',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'disgust',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'trust',
#  'joy',
#  'joy',
#  'anticipation',
#  'anticipation',
#  'sadness',
#  'disgust',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anticipation',
#  'joy',
#  'anticipation',
#  'disgust',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'fear',
#  'disgust',
#  'joy',
#  'disgust',
#  'sadness',
#  'anger',
#  'trust',
#  'joy',
#  'disgust',
#  'joy',
#  'fear',
#  'disgust',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'trust',
#  'joy',
#  'anticipation',
#  'joy',
#  'disgust',
#  'disgust',
#  'joy',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'fear',
#  'sadness',
#  'joy',
#  'disgust',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'anticipation',
#  'sadness',
#  'sadness',
#  'disgust',
#  'anticipation',
#  'joy',
#  'sadness',
#  'disgust',
#  'disgust',
#  'joy',
#  'disgust',
#  'anticipation',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'trust',
#  ...]

# %%
test_df['predict'] = predict_list
# test_df

# %%
output_df = test_df[['tweet_id', 'predict']]
output_df = output_df.rename(columns={'tweet_id':'id', 'predict':'emotion'})
# output_df

# %%
output_df.to_csv('../output/BiLSTM_epoch_50.csv', index=False, header=True)
